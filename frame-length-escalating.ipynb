# %%
# !tshark -n -r escalating.pcap -T fields -Eheader=y -e frame.number -e frame.len > frame.len

# %%
import pandas as pd

# %%
df=pd.read_table("frame.len")
df.head()
# Out:
#    frame.number  frame.len
# 0             1         62
# 1             2         62
# 2             3         60
# 3             4        126
# 4             5         60

# %%
df["frame.len"].describe()
# Out:
# count    14092.000000
# mean       599.722396
# std        678.178177
# min         42.000000
# 25%         60.000000
# 50%        126.000000
# 75%       1514.000000
# max       1514.000000
# dtype: float64

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df["frame.len"].plot(style=".", alpha=0.2,figsize=(10,6))
title("Frame length Escalating")
ylabel("bytes")
xlabel("frame number")
