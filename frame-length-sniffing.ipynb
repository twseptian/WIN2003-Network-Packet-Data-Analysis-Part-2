# %%
# !tshark -n -r sniffing.pcap -T fields -Eheader=y -e frame.number -e frame.len > frame.len

# %%
import pandas as pd

# %%
df=pd.read_table("frame.len")
df.head()
# Out:
#    frame.number  frame.len
# 0             1         54
# 1             2         60
# 2             3         54
# 3             4         60
# 4             5         54

# %%
df["frame.len"].describe()
# Out:
# count    10488.000000
# mean       388.274981
# std        568.519950
# min         42.000000
# 25%         60.000000
# 50%         60.000000
# 75%        343.250000
# max       1514.000000
# dtype: float64

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df["frame.len"].plot(style=".", alpha=0.2,figsize=(10,6))
title("Frame length Sniffing")
ylabel("bytes")
xlabel("frame number")
